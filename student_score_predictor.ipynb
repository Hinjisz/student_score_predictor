# %% [markdown]
# <a href="https://colab.research.google.com/github/Hinjisz/student_score_predictor/blob/main/mlproject1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Study hours (X)
X = np.array([[1],[2],[3],[4],[5],[6],[7],[8]])

# Marks (y)
y = np.array([35,42,48,60,63,72,78,90])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)

print("X_test:", X_test)
print("Predictions:", predictions)
print("Actual:", y_test)
# Out:
# X_test: [[1]
#  [8]]
# Predictions: [35. 86.]
# Actual: [35 90]

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
# Out:
# MSE: 8.0

# %%
print(model.predict([[0]]))  # Predict marks for 0 hours study
# Out:
# [27.71428571]

# %%
import matplotlib.pyplot as plt

# Plot actual data
plt.scatter(X, y)

# Plot regression line
plt.plot(X, model.predict(X))

plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Study Hours vs Marks")

plt.show()
